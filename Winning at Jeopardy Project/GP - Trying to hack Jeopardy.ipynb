# %% [markdown]
# # Winning Jeopardy Project
#
# Jeopardy is a popular TV show in the US where participants answer questions to win money. It's been running for many years, and is a major force in popular culture. Rules for playing Jeopardy are [here](!https://tag.rutgers.edu/wp-content/uploads/2014/05/Jeopardy-instructions.pdf)
#
# Imagine that you want to compete on Jeopardy, and you're looking for any way to win. In this project, you'll work with a dataset of Jeopardy questions to figure out some patterns in the questions that could help you win.
#
# The dataset is named jeopardy.csv, and contains 20000 rows from the beginning of a full dataset of Jeopardy questions, which you can download [here](!https://www.reddit.com/r/datasets/comments/1uyd0t/200000_jeopardy_questions_in_a_json_file).
#
#
# Columns description:
#
# - `Show Number` - the Jeopardy episode number
# - `Air Date` - the date the episode aired
# - `Round` - the round of Jeopardy
# - `Category` - the category of the question
# - `Value` - the number of dollars the correct answer is worth
# - `Question` - the text of the question
# - `Answer` - the text of the answer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import random

from scipy.stats import chisquare
from scipy.stats import chi2_contingency

# %%
jeopardy = pd.read_csv('jeopardy.csv')
jeopardy.head(5)
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %% [markdown]
# # Normalizing Text

# %%
print(jeopardy.columns)
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %%
columns_list = list(jeopardy.columns)

for column in range(len(columns_list)):
    columns_list[column] = columns_list[column].strip()
jeopardy.columns = columns_list
jeopardy.columns
# Out:
# Index(['Show Number', 'Air Date', 'Round', 'Category', 'Value', 'Question',
#        'Answer'],
#       dtype='object')

# %% [markdown]
# # Normalizing Columns

# %%
jeopardy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 7 columns):
# Show Number    19999 non-null int64
# Air Date       19999 non-null object
# Round          19999 non-null object
# Category       19999 non-null object
# Value          19999 non-null object
# Question       19999 non-null object
# Answer         19999 non-null object
# dtypes: int64(1), object(6)
# memory usage: 1.1+ MB

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub("[^A-Za-z0-9\s]", "", text) # the regex removes any punctuation
    text = re.sub("[\s+]", " ", text)
    return text
    
jeopardy['clean_question'] = jeopardy['Question'].apply(normalize_text)
jeopardy['clean_answer'] = jeopardy['Answer'].apply(normalize_text)

# %%
def normalize_value(text):
    text = re.sub("[^A-Za-z0-9\s]", "", text)
    try:
        text = int(text)
    except Exception:
        text = 0
    return text

jeopardy['clean_value'] = jeopardy['Value'].apply(normalize_value)

# %%
jeopardy['Air Date'] = pd.to_datetime(jeopardy['Air Date'])

# %%
jeopardy.head(5)
# Out:
#    Show Number   Air Date      Round                         Category Value  \
# 0         4680 2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680 2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680 2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680 2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680 2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer  \
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams
#
#                                       clean_question clean_answer  clean_value
# 0  for the last 8 years of his life galileo was u...   copernicus          200
# 1  no 2 1912 olympian football star at carlisle i...   jim thorpe          200
# 2  the city of yuma in this state has a record av...      arizona          200
# 3  in 1963 live on the art linkletter show this c...    mcdonalds          200
# 4  signer of the dec of indep framer of the const...   john adams          200

# %%
jeopardy.dtypes
# Out:
# Show Number                int64
# Air Date          datetime64[ns]
# Round                     object
# Category                  object
# Value                     object
# Question                  object
# Answer                    object
# clean_question            object
# clean_answer              object
# clean_value                int64
# dtype: object

# %% [markdown]
# # Answers in Questions
#
# In order to figure out whether to study past questions, study general knowledge, or not study it all, it would be helpful to figure out two things:
#
# - How often the answer can be used for a question.
# - How often questions are repeated.
#
# We can answer the first question by seeing how many times words in the answer also occur in the question.
#
# We can answer the second question by seeing how often complex words (> 6 characters) reoccur.

# %% [markdown]
# ## How often the answer can be used for question?

# %%
def count_matches(row):
    split_answer = row['clean_answer'].split()
    split_question = row['clean_question'].split()

    if 'the' in split_answer:
        split_answer.remove('the')
    
    if len(split_answer) == 0:
        return 0

    match_count = 0
    for word in split_answer:
        if word in split_question:
            match_count += 1
    
    return match_count/len(split_answer)

jeopardy['answer_in_question'] = jeopardy.apply(count_matches, axis=1)

# %%
jeopardy['answer_in_question'].mean()
# Out:
# 0.05900196524977763

# %% [markdown]
# In the operations above, we wanted to see if the answer to a question is inside the question.
#
# With an occuring percentage of just 6%, it means that it is nearly impossible to be able to answer a question by simply hearing it. Thus, this would mean that it requires study time in order to answer Jeopardy questions.

# %% [markdown]
# ## How often questions are repeated?

# %%
question_overlap = []
terms_used = set()

jeopardy = jeopardy.sort_values(by='Air Date')

for index, row in jeopardy.iterrows():
    split_question = row['clean_question'].split(' ')
    split_question = [q for q in split_question if len(q) > 5]
    
    match_count = 0
    for word in split_question:
        if word in terms_used:
            match_count += 1
    for word in split_question:
        terms_used.add(word)

    if len(split_question) > 0:
        match_count /= len(split_question)
    question_overlap.append(match_count)
    
jeopardy['question_overlap'] = question_overlap
jeopardy['question_overlap'].mean()
# Out:
# 0.6876260592169802

# %% [markdown]
# In the function above, we eliminated all the words that are less than 6 characthers in order to allow for more complex words to be
#
# It looks that around 69% of the terms in old questions are being repeated in the new questions. This looks only at words and not at phrases. Since the dataset that we have gave us access to only 10% of the phrases, the result is a quite insignificant, but it does allow us to look into how the questions are being recycled.

# %% [markdown]
# # Low Value vs High Value Questions

# %%
def determine_value(row):
    value = 0
    if row['clean_value'] > 800:
        value = 1
    return value

jeopardy['high_value'] = jeopardy.apply(determine_value, axis=1)

# %%
def count_usage(term):
    low_count = 0
    high_count = 0
    
    for index, row in jeopardy.iterrows():
        if term in row['clean_question'].split(" "):
            if row['high_value'] == 1:
                high_count += 1
            else:
                low_count += 1
    return high_count, low_count

# %%
terms_used
# Out:
# {'territorynunavut',
#  'impulsive',
#  'motorwagen',
#  'leaders',
#  'billboard',
#  'liberata',
#  'concoction',
#  'intake',
#  'cytosine',
#  'associates',
#  'highwire',
#  'hoekstras',
#  'garbage',
#  'colter',
#  'schultz',
#  'whistlestop',
#  'alcatraz',
#  'comets',
#  'bianco',
#  'founded',
#  'consisted',
#  'sheryl',
#  'beggars',
#  'liquids',
#  'actons',
#  'instructed',
#  'fabriano',
#  'speechless',
#  '12letter',
#  'halleys',
#  'langera',
#  'lipton',
#  'hrefhttpwwwjarchivecommedia20010718j12jpg',
#  'romano',
#  'siddim',
#  'belmont',
#  'babysitters',
#  'carpet',
#  '125000',
#  'miserables',
#  'targetblankhanda',
#  'hrefhttpwwwjarchivecommedia20050502dj18jpg',
#  'mcneese',
#  'targetblankputs',
#  '900000',
#  'luhsootoo',
#  'robbie',
#  'wilhelm',
#  'replay',
#  'disappear',
#  'anagram',
#  'ingest',
#  'conways',
#  'website',
#  'donelson',
#  'dominata',
#  'sniffling',
#  'hrefhttpwwwjarchivecommedia20060601j24jpg',
#  'youngest',
#  'stimulate',
#  'butchart',
#  '6pronged',
#  'neuman',
#  'scottsboro',
#  'progressive',
#  'abroad',
#  'subsidence',
#  'gauche',
#  'valiant',
#  'contagion',
#  'kohoutek',
#  'protect',
#  'chalus',
#  'executing',
#  'hrefhttpwwwjarchivecommedia20070112dj26ajpg',
#  'deighton',
#  'mistral',
#  'illilouette',
#  'wheels',
#  'chicagobased',
#  'survive',
#  'lacteous',
#  'grosse',
#  'osakaborn',
#  'indies',
#  'roentgen',
#  'harlot',
#  'helsing',
#  'crawfords',
#  'starts',
#  'capita',
#  'ginevra',
#  'needles',
#  'exhibiting',
#  'woolly',
#  'pernambuco',
#  'gollan',
#  'hamlisch',
#  'vulpecula',
#  'wharfs',
#  'duplicate',
#  'crushing',
#  'rawling',
#  'hammock',
#  'trivialize',
#  'leverrier',
#  'coinciding',
#  'washington',
#  'tuilaepa',
#  'boards',
#  'littlefoot',
#  'demonstrate',
#  'exhale',
#  'pottery',
#  'sendup',
#  'furtrading',
#  'kennedy',
#  'florida',
#  'popularity',
#  'victor',
#  'compounds',
#  'announce',
#  'coconuts',
#  'bonham',
#  'salehs',
#  'peacemaker',
#  'hoopshooting',
#  'carters',
#  'strictly',
#  'shortcakes',
#  'wesley',
#  'rochesters',
#  'targetblankvery',
#  'correct',
#  'mantra',
#  'descends',
#  'columbia',
#  'chantilly',
#  'encourage',
#  'isurvivori',
#  'citrus',
#  'targetblanksignsa',
#  'prospected',
#  'dressmaker',
#  'stolichanya',
#  'stoker',
#  'givens',
#  'lassie',
#  'roller',
#  'languages',
#  'humorous',
#  'volcanos',
#  'horton',
#  'format',
#  'jainism',
#  'sensitively',
#  'featurea',
#  'invadee',
#  'enforces',
#  'hrefhttpwwwjarchivecommedia20070115j04jpg',
#  'illustrates',
#  'hamadryad',
#  'contrary',
#  'backwards',
#  'greshams',
#  'aerospace',
#  'ricans',
#  'robber',
#  'dividing',
#  'kuryakin',
#  'decade',
#  'feather',
#  'angelic',
#  'divorces',
#  'dismissed',
#  'meeting',
#  'ichiro',
#  'mendeleev',
#  'satirizes',
#  'speedway',
#  'reclining',
#  'exgerman',
#  'pressing',
#  'malmaisonbound',
#  'farming',
#  'havanas',
#  'mankind',
#  'defenses',
#  'extract',
#  'policeman',
#  'civilians',
#  'gatherings',
#  'cabriole',
#  'degeneres',
#  'hairdresser',
#  'facing',
#  'slovenia',
#  'laurents',
#  'dominique',
#  'transplanted',
#  'socony',
#  'supplies',
#  'increase',
#  'online',
#  'unclearly',
#  'blackfoot',
#  'firewood',
#  'phoebes',
#  'vespasian',
#  'slickers',
#  'washer',
#  'sequential',
#  'shorter',
#  'samson',
#  'instant',
#  'brackets',
#  'fairest',
#  'booths',
#  'politicalsounding',
#  'lodestone',
#  'plucked',
#  'hrefhttpwwwjarchivecommedia20120111dj28jpg',
#  'ranges',
#  'apotheosis',
#  'washing',
#  'delysia',
#  'drowning',
#  'replicants',
#  'understory',
#  'heliocentric',
#  'madame',
#  'lysander',
#  'massive',
#  'grader',
#  'hrefhttpwwwjarchivecommedia20101104j29wmvoprah',
#  'yourselfin',
#  'decomposed',
#  'bavetta',
#  'served',
#  'sideshow',
#  'chincha',
#  'volleyball',
#  'rumored',
#  'conningham',
#  'rousing',
#  'searching',
#  'swinelike',
#  'hrefhttpwwwjarchivecommedia20001123dj19wmvithese',
#  'hrefhttpwwwjarchivecommedia20111021dj30jpg',
#  'ambassador',
#  'homeland',
#  'eylashes',
#  'wildlife',
#  'sharing',
#  'knighted',
#  'mealtime',
#  'nazarbayev',
#  'justin',
#  'decrevisse',
#  'boyfriend',
#  'southeast',
#  'agitator',
#  'mission',
#  'shadesa',
#  'woldegiorgis',
#  'weehawken',
#  'hemoglobin',
#  'fa18ef',
#  'winston',
#  'belgians',
#  'lewiston',
#  'viceroyalty',
#  'hrefhttpwwwjarchivecommedia20050323dj14mp3songa',
#  'wingless',
#  'targetblankall',
#  'sparks',
#  'conductors',
#  'forces',
#  'grandslam',
#  'legislative',
#  'hurricane',
#  'capitalized',
#  'seabird',
#  'blowgun',
#  'beijing',
#  'brilliance',
#  'californians',
#  'windsor',
#  'puppets',
#  'foxglove',
#  'binoculars',
#  'blinked',
#  'alberto',
#  'sickly',
#  'outlived',
#  'resembling',
#  'pamela',
#  'wanghia',
#  'hiring',
#  'billings',
#  'clergyman',
#  'ciceros',
#  '191618',
#  'waterworld',
#  'hrefhttpwwwjarchivecommedia20080521dj28jpg',
#  'hrefhttpwwwjarchivecommedia20080310dj21jpg',
#  'sciences',
#  'counterfeits',
#  'sturnidae',
#  'recovered',
#  'paprika',
#  'departure',
#  'ferraro',
#  'childs',
#  'revelations',
#  'gorrell',
#  'sicilian',
#  'saleswoman',
#  'approachable',
#  'hrefhttpwwwjarchivecommedia20071203dj22mp3slapping',
#  'champions',
#  '10event',
#  'supposedly',
#  'buchan',
#  'birmingham',
#  'lollobrigida',
#  'chryssomallis',
#  'simile',
#  'booker',
#  'ringlike',
#  'brontes',
#  'birdlike',
#  'memphisbased',
#  'derringer',
#  'prestige',
#  'incurs',
#  'highways',
#  'williams',
#  'mehmed',
#  'hairier',
#  'augustines',
#  'payroll',
#  'fundamental',
#  'deposit',
#  'sideout',
#  'eventoed',
#  'bewitching',
#  'merchant',
#  'lookalike',
#  'decidedly',
#  'tenderloin',
#  'freddie',
#  'nationwide',
#  'hrefhttpwwwjarchivecommedia20060515j29jpg',
#  'kickoffs',
#  'gasessmart',
#  'germanic',
#  'accumulation',
#  'nathan',
#  'coleridge',
#  'indochina',
#  'lancaster',
#  'livingstone',
#  'mossad',
#  'narrates',
#  'traini',
#  'sportswriter',
#  'fairground',
#  '250000',
#  'tarsus',
#  'dominion',
#  'leslies',
#  'garthe',
#  'jesters',
#  'brooklyns',
#  'pardon',
#  'tippecanoe',
#  'telecast',
#  'antonios',
#  'hrefhttpwwwjarchivecommedia20051004dj24jpg',
#  'eminem',
#  'seawolf',
#  'redcockaded',
#  'purposes',
#  'obannon',
#  'dorothys',
#  'cincinnati',
#  'instructs',
#  'restrict',
#  'halfghost',
#  'vacation',
#  'hrefhttpwwwjarchivecommedia20060303dj28jpg',
#  'preservation',
#  'harrelson',
#  'mathematics',
#  'cloudy',
#  'barnum',
#  'recoup',
#  'popmart',
#  'vincis',
#  'shipboard',
#  'entendu',
#  'packaged',
#  'gristly',
#  'mortimer',
#  'norton',
#  'boozing',
#  'ballparks',
#  'archaic',
#  'licensed',
#  'amenhotep',
#  'brownsville',
#  'experience',
#  'tastiersounding',
#  'boswell',
#  'wolverine',
#  'physician',
#  'bashing',
#  'chukutien',
#  'compendious',
#  'allens',
#  'blowing',
#  'glance',
#  'milwaukees',
#  'certiorari',
#  'ustinov',
#  'marielouise',
#  'charley',
#  'congressmans',
#  'illusion',
#  'baruch',
#  'gilleys',
#  'armageddon',
#  'purports',
#  'thenrecord',
#  'hrefhttpwwwjarchivecommedia20070330j02jpg',
#  'adrift',
#  'hrefhttpwwwjarchivecommedia20091229j04wmvjimmy',
#  'carafe',
#  'pheever',
#  'christopher',
#  'targetblankpeoplea',
#  'bloated',
#  'sunflowers',
#  'secretiveness',
#  'slavers',
#  'referring',
#  'vineyards',
#  'dependency',
#  'hrefhttpwwwjarchivecommedia20091002j28jpg',
#  '3lobed',
#  'onetime',
#  'copyright',
#  'dakota',
#  'oyster',
#  'targetblankbread',
#  'lindbergh',
#  'packer',
#  'rodrigues',
#  'simple',
#  'wouldbe',
#  'horrifying',
#  'myrtle',
#  'spreader',
#  'guidance',
#  '1rated',
#  '8letter',
#  'winwood',
#  'guerrilla',
#  'hrefhttpwwwjarchivecommedia20110422dj05wmvjimmy',
#  'adopts',
#  'beings',
#  'viacom',
#  'tchaikovsky',
#  'headgear',
#  'inhibiting',
#  'hopkins',
#  'vacuum',
#  'panhandle',
#  'avantgarde',
#  'tiflin',
#  'winglike',
#  'hirofumi',
#  'linmanuel',
#  'metasearch',
#  'hrefhttpwwwjarchivecommedia20071113dj09jpg',
#  'street',
#  'brandsa',
#  'vetoed',
#  'kavandi',
#  'offically',
#  'commonly',
#  'abounding',
#  'pittsburgh',
#  'figured',
#  'borrow',
#  'grayleaved',
#  'thirdborn',
#  'curing',
#  'matjes',
#  'wraparound',
#  'tombstone',
#  'dogberts',
#  'superspy',
#  'laurence',
#  'markings',
#  'heroine',
#  'organizational',
#  'galley',
#  'pahoehoe',
#  'outline',
#  'sardinia',
#  'returned',
#  'puerto',
#  'affect',
#  'gouged',
#  'contributes',
#  'tweeds',
#  'wreath',
#  'dashing',
#  'travelers',
#  'insult',
#  'souptime',
#  'erected',
#  'bucket',
#  'pepsico',
#  'publications',
#  'visions',
#  'calypso',
#  'viewer',
#  'pollution',
#  'hurling',
#  'hawaiians',
#  'hrefhttpwwwjarchivecommedia20090929j16jpg',
#  'mooresville',
#  'targetblankheresa',
#  'reedited',
#  'arthro',
#  'swollen',
#  'screenplay',
#  'lifeless',
#  'persil',
#  'allowance',
#  'understand',
#  'coconut',
#  'pharmacy',
#  'asuncion',
#  'sauerbraten',
#  'topselling',
#  'fumbled',
#  'aardvark',
#  'hrefhttpwwwjarchivecommedia20020509j04mp3herea',
#  'narrator',
#  'skycoloured',
#  'tarkanian',
#  'whirlpool',
#  'windpipe',
#  'destinations',
#  'pigment',
#  'vinylcovered',
#  'subdivided',
#  'reputedly',
#  'houlihans',
#  'flatpanel',
#  'overweight',
#  'salems',
#  'martian',
#  'civilian',
#  'beanfield',
#  'headaches',
#  'saltwatera',
#  'joachimsthal',
#  'inflammation',
#  'feminine',
#  'hrefhttpwwwjarchivecommedia20060317j27jpg',
#  'whisked',
#  'paddies',
#  'fanning',
#  'streetcar',
#  'occurs',
#  'merrylegs',
#  'conversation',
#  'steppe',
#  'puritan',
#  'oneals',
#  'reputed',
#  'mindanao',
#  'viewed',
#  'aesculus',
#  'clinica',
#  'shiite',
#  'staccato',
#  'hydrochloride',
#  'hrefhttpwwwjarchivecommedia20091218dj27jpg',
#  'shoots',
#  'stanford',
#  'instrument',
#  'goldeneye',
#  'hrefhttpwwwjarchivecommedia20050502j04jpg',
#  'schuberts',
#  'subatomic',
#  'indigenous',
#  'sortof',
#  'delinquent',
#  'sabrina',
#  'hrefhttpwwwjarchivecommedia20060725dj25wmvjon',
#  'professionailly',
#  'competition',
#  'lowlevel',
#  'traumdeutung',
#  'hrefhttpwwwjarchivecommedia20091001dj07ajpg',
#  'urnammu',
#  'hrefhttpwwwjarchivecommedia20100528dj05jpg',
#  'denoting',
#  'halfhearted',
#  'elburz',
#  'eduardo',
#  'unusually',
#  'buddha',
#  'change',
#  'exalted',
#  'mangetout',
#  'newsweek',
#  'tovarich',
#  'copernicus',
#  'dromio',
#  'quervain',
#  'musset',
#  'balkans',
#  'chalabi',
#  'alfredo',
#  'igloos',
#  'spiceinfused',
#  'nutrilite',
#  'utopian',
#  'invaded',
#  'waterman',
#  'meiwontreply',
#  'okinawan',
#  'dominick',
#  'stlouis',
#  'hrefhttpwwwjarchivecommedia20091117j30wmvalex',
#  'silently',
#  'conspiracy',
#  'loretta',
#  'object',
#  'rabies',
#  'stately',
#  'fibers',
#  'dissent',
#  'reprimand',
#  'sneeze',
#  'embedded',
#  'carrier',
#  'christchurch',
#  'overhang',
#  'booking',
#  'westminster',
#  'damage',
#  'exotic',
#  'psyche',
#  'gomateshwara',
#  'unconfined',
#  'rhinoplasty',
#  'governed',
#  'computergenerated',
#  'negative',
#  'mcentires',
#  'inaugurated',
#  'sticks',
#  'nonsteroidal',
#  'lotions',
#  'allnut',
#  'hottest',
#  'hrefhttpwwwjarchivecommedia20100101j29ajpg',
#  'crucify',
#  'durers',
#  'cytology',
#  'specialists',
#  'cheddar',
#  'educationeste',
#  'legitimate',
#  'hatcher',
#  'coproduced',
#  'colonize',
#  'archangel',
#  'innsmouth',
#  'farther',
#  'malones',
#  'bellerophon',
#  'kibbutz',
#  'etesian',
#  'expire',
#  'counterparts',
#  'steelmaking',
#  'weiser',
#  'polonius',
#  'stunta',
#  'aviation',
#  'hrefhttpwwwjarchivecommedia20101119dj15jpg',
#  '178793',
#  'nutritionally',
#  'poetical',
#  'prevent',
#  'paddle',
#  'apprentice',
#  'caucus',
#  'visually',
#  'finland',
#  'huangti',
#  'natures',
#  'methane',
#  'thrills',
#  'hrefhttpwwwjarchivecommedia20041109dj07mp3herea',
#  'prestidigitation',
#  'hummus',
#  'ethereal',
#  'waterway',
#  'dayton',
#  'earnestlooking',
#  'spikeliterally',
#  'priests',
#  'popcorn',
#  'grasshopper',
#  'hrefhttpwwwjarchivecommedia20100111j10jpg',
#  'mcentire',
#  'morehouse',
#  'metropolitan',
#  'bordens',
#  'inquisition',
#  'enjoyment',
#  'camera',
#  'handbook',
#  'acclaimed',
#  'crystallize',
#  'gardner',
#  'commonwealth',
#  'orientation',
#  'cooperate',
#  'hrefhttpwwwjarchivecommedia20100421dj05jpg',
#  'springs',
#  'presidential',
#  'eventually',
#  'interview',
#  'diaghilevs',
#  'reptiles',
#  'solved',
#  'dealing',
#  'pretends',
#  'counsel',
#  'sharklike',
#  'repaired',
#  'touted',
#  'targetblankrelativea',
#  'alarcons',
#  'navarone',
#  'hrefhttpwwwjarchivecommedia20050119j13jpg',
#  'stencil',
#  'secretarial',
#  'bledsoe',
#  'caithness',
#  'courthouse',
#  'beatnik',
#  'unbeknownst',
#  'audience',
#  'abrams',
#  'sponsors',
#  'bartlett',
#  'superhighway',
#  'hickoryflavored',
#  'indents',
#  'lanatus',
#  'hrefhttpwwwjarchivecommedia20060303dj26ajpg',
#  'fettuccine',
#  'guarantee',
#  'paddling',
#  'tristram',
#  'drifted',
#  'reaper',
#  'attends',
#  'baconwrapped',
#  'tuliptree',
#  'dreadfully',
#  'platter',
#  'bridenow',
#  'airplane',
#  'restless',
#  'renovated',
#  'lorraine',
#  'horizon',
#  'successor',
#  'finals',
#  'tomlins',
#  'brooklyn',
#  'etruscan',
#  'followers',
#  'abstract',
#  'xylophone',
#  'romanus',
#  'julianne',
#  'regarding',
#  'musial',
#  'nuprin',
#  'spoons',
#  'lollipop',
#  'notorious',
#  'ancestor',
#  'ailment',
#  'patriotic',
#  'yesssssssshe',
#  'vieira',
#  'ubiquinone',
#  'theatre',
#  'privileges',
#  'salieri',
#  'porizkova',
#  'artist',
#  'barbie',
#  'charismatic',
#  'kirschner',
#  'aykroyd',
#  'sheena',
#  'hrefhttpwwwjarchivecommedia20060515j08wmvmovea',
#  'carnahan',
#  'sholem',
#  'smokin',
#  'holeia',
#  'ambushed',
#  'border',
#  '371year',
#  'wondrin',
#  'keller',
#  'layers',
#  'herders',
#  'grammywinning',
#  'allwhite',
#  'selfreferential',
#  'crossbow',
#  'socialist',
#  'bracelets',
#  'described',
#  'boyhood',
#  'centuriesold',
#  'device',
#  'commoner',
#  'districts',
#  'strangers',
#  'parlezvous',
#  'kinshasa',
#  'ignores',
#  'nocout',
#  'hrefhttpwwwjarchivecommedia20090105dj05ajpg',
#  'persistent',
#  'hedonism',
#  'hrefhttpwwwjarchivecommedia20050307dj26ajpg',
#  'athenian',
#  'bourbon',
#  'traveler',
#  'engineless',
#  'radioactive',
#  'narrow',
#  'cafeteria',
#  'cameraless',
#  'lighters',
#  'willowes',
#  'reelection',
#  'blutarsky',
#  'argentinean',
#  'webcam',
#  'wimbledon',
#  'scroll',
#  'ivanovich',
#  'evolves',
#  'shelled',
#  'hrefhttpwwwjarchivecommedia20060213j01wmvjon',
#  'crawled',
#  'hrefhttpwwwjarchivecommedia20090211dj14ajpg',
#  'anchor',
#  'vaults',
#  'spouterinn',
#  'theaters',
#  'lechery',
#  'passive',
#  'shopkeepers',
#  'firedog',
#  'comics',
#  'cooperations',
#  '4chanorg',
#  'presentsa',
#  'quatrains',
#  'itasca',
#  'thrower',
#  'fadduh',
#  'hermitage',
#  'heavens',
#  'dispersed',
#  '3stage',
#  'mancha',
#  'sarumans',
#  'apiculturist',
#  'aquitaine',
#  'hrefhttpwwwjarchivecommedia20091007j08mp3herea',
#  'breads',
#  'participating',
#  'colleges',
#  'average',
#  'hieroglyphics',
#  'witnessed',
#  'governing',
#  'supremacy',
#  'jacobsons',
#  'kachina',
#  'botanically',
#  'quadrantids',
#  'inward',
#  'province',
#  'proper',
#  'fishoutofwater',
#  'outland',
#  'lesseps',
#  'barbaric',
#  'slumber',
#  'burglary',
#  'paricutin',
#  'youthful',
#  '9yearrun',
#  'structure',
#  'indulge',
#  'belted',
#  'hoppin',
#  'guides',
#  'judges',
#  'mccain',
#  'hemingway',
#  'martini',
#  'tocqueville',
#  'brigand',
#  'warnerlambert',
#  'ruffled',
#  'weddell',
#  'involving',
#  'durban',
#  'baskin',
#  'number',
#  'transparently',
#  'odious',
#  'rockfish',
#  'adamant',
#  'analyzed',
#  'interim',
#  'adamantine',
#  'washingtonians',
#  'portia',
#  'fiercest',
#  'walken',
#  'figurea',
#  'trigger',
#  'bronsons',
#  'carter',
#  'morphine',
#  'loneliness',
#  'stormed',
#  'nobelist',
#  'knesset',
#  'plumber',
#  'oversees',
#  'adenahopewell',
#  'berakah',
#  'guggenheim',
#  'thornton',
#  'trains',
#  'temptation',
#  'kingpin',
#  'salammbo',
#  'bibleinspired',
#  'guernsey',
#  'cockney',
#  'lovebites',
#  'hrefhttpwwwjarchivecommedia20050502j04ajpg',
#  'planes',
#  'calendar',
#  'singable',
#  'maintained',
#  'predecessor',
#  'locomotives',
#  'tafari',
#  'pentium',
#  'gascooled',
#  'graphical',
#  'ambulanceone',
#  'mutant',
#  'mahzor',
#  'awaytheres',
#  'nutmobile',
#  'redeems',
#  'sensibility',
#  'unfavorable',
#  'personnel',
#  'hrefhttpwwwjarchivecommedia20060227dj27jpg',
#  'beauregard',
#  ...}

# %%
count_usage('schultz')
# Out:
# (1, 0)

# %%
terms_used_list = list(terms_used)

random.seed(42)
comparison_terms = [random.choice(terms_used_list) for i in range(10)]
print("The random sampled terms are:", comparison_terms)

observed_expected = []

for term in comparison_terms:
    observed_expected.append(count_usage(term))
    
observed_expected
# Out:
# [(0, 1),
#  (0, 1),
#  (1, 1),
#  (0, 1),
#  (5, 6),
#  (1, 2),
#  (2, 8),
#  (1, 3),
#  (1, 1),
#  (0, 1)]

# %%
high_value_count = jeopardy[jeopardy['high_value']==1].shape[0]
low_value_count = jeopardy[jeopardy['high_value']==0].shape[0]

chi_squared = []

for element in observed_expected:
    total = sum(element)
    total_prop = total / len(jeopardy.index)
    expected_high_value_count = total_prop * high_value_count
    expected_low_value_count = total_prop * low_value_count

    observed = np.array([element[0], element[1]])
    expected = np.array([expected_high_value_count, expected_low_value_count])
    
    chi_squared.append(chisquare(observed, expected))
    
chi_squared
# Out:
# [Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=0.4448774816612795, pvalue=0.5047776487545996),
#  Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469),
#  Power_divergenceResult(statistic=1.5150423082236086, pvalue=0.21837128417807639),
#  Power_divergenceResult(statistic=0.03188116723440362, pvalue=0.8582887163235293),
#  Power_divergenceResult(statistic=0.36767906209032747, pvalue=0.5442721040962595),
#  Power_divergenceResult(statistic=0.02636443308440769, pvalue=0.871013484688921),
#  Power_divergenceResult(statistic=0.4448774816612795, pvalue=0.5047776487545996),
#  Power_divergenceResult(statistic=0.401962846126884, pvalue=0.5260772985705469)]

# %%
# Transform the observed_expected values to a dataframe
results = pd.DataFrame(observed_expected, 
                       index=comparison_terms,
                      columns=['Low value count', 'Hight value count']
                      )

# Adding the chi-square and p-value results as columns
results['Chi'] = chi_squared
results[['Chi Square', 'p value']] = pd.DataFrame(results.Chi.tolist(), index= results.index)
results.drop('Chi', axis= 1, inplace= True)

# Display results
results
# Out:
#           Low value count  Hight value count  Chi Square   p value
# winglike                0                  1    0.401963  0.526077
# fleamail                0                  1    0.401963  0.526077
# sixteen                 1                  1    0.444877  0.504778
# gizzards                0                  1    0.401963  0.526077
# direct                  5                  6    1.515042  0.218371
# heating                 1                  2    0.031881  0.858289
# covering                2                  8    0.367679  0.544272
# slugger                 1                  3    0.026364  0.871013
# pigments                1                  1    0.444877  0.504778
# shootout                0                  1    0.401963  0.526077
